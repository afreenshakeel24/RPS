# %%
import unittest
from testrpsgame import Testrpsgame
from testrpshelp import Testrpshelp

def my_suite():
    suite = unittest.TestSuite()
    result = unittest.TestResult()
    suite.addTest(unittest.makeSuite(Testrpsgame))
    suite.addTest(unittest.makeSuite(Testrpshelp))
    runner = unittest.TextTestRunner()
    print(runner.run(suite))
my_suite()
# Out:
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# test_display (testrpsgame.Testrpsgame) ... ok
# test_game_rps (testrpsgame.Testrpsgame) ... ok
# test_traditionalmodel (testrpsgame.Testrpsgame) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.002s
#
# OK
# .....
# You have to choose from:
# Rock
# Paper
# Scissors
#
#
#  How does it work?
#
#
# Rock crushes Scissors
#  Scissors cuts Paper
#  Paper covers Rock
# You have to choose from:
# Rock
# Paper
# Scissors
#
#
#  How does it work?
#
#
# Rock crushes Scissors
#  Scissors cuts Paper
#  Paper covers Rock
# You have to choose from:
# Rock
# Paper
# Scissors
#
#
#  How does it work?
#
#
# Rock crushes Scissors
#  Scissors cuts Paper
#  Paper covers Rock
# You have to choose from:
# Rock
# Paper
# Scissors
#
#
#  How does it work?
#
#
# Rock crushes Scissors
#  Scissors cuts Paper
#  Paper covers Rock
# You have to choose from:
# ...
