# %%
import playthisgame

# %%
a1 = playthisgame.Maingame()
a1.display()
# Out:
# You have to choose between 0 and 73. Enter 0 to choose the Traditional version or enter 73 to choose Sheldon Cooper's version
# Player chooses : 0
# YOU HAD ONE TINY JOB
